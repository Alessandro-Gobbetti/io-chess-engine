# %%
text = """
KBBBvK.rtbw
KBBNvK.rtbw
KBBPvK.rtbw
KBBvK.rtbw
KBBvKB.rtbw
KBBvKN.rtbw
KBBvKP.rtbw
KBBvKQ.rtbw
KBBvKR.rtbw
KBNNvK.rtbw
KBNPvK.rtbw
KBNvK.rtbw 
KBNvKB.rtbw
KBNvKN.rtbw
KBNvKP.rtbw
KBNvKQ.rtbw
KBNvKR.rtbw
KBPPvK.rtbw
KBPvK.rtbw 
KBPvKB.rtbw
KBPvKN.rtbw
KBPvKP.rtbw
KBPvKQ.rtbw
KBPvKR.rtbw
KBvK.rtbw  
KBvKB.rtbw 
KBvKN.rtbw 
KBvKP.rtbw 
KNNNvK.rtbw
KNNPvK.rtbw
KNNvK.rtbw 
KNNvKB.rtbw
KNNvKN.rtbw
KNNvKP.rtbw
KNNvKQ.rtbw
KNNvKR.rtbw
KNPPvK.rtbw
KNPvK.rtbw 
KNPvKB.rtbw
KNPvKN.rtbw
KNPvKP.rtbw
KNPvKQ.rtbw
KNPvKR.rtbw
KNvK.rtbw  
KNvKN.rtbw 
KNvKP.rtbw 
KPPPvK.rtbw
KPPvK.rtbw 
KPPvKB.rtbw
KPPvKN.rtbw
KPPvKP.rtbw
KPPvKQ.rtbw
KPPvKR.rtbw
KPvK.rtbw  
KPvKP.rtbw 
KQBBvK.rtbw
KQBNvK.rtbw
KQBPvK.rtbw
KQBvK.rtbw 
KQBvKB.rtbw
KQBvKN.rtbw
KQBvKP.rtbw
KQBvKQ.rtbw
KQBvKR.rtbw
KQNNvK.rtbw
KQNPvK.rtbw
KQNvK.rtbw 
KQNvKB.rtbw
KQNvKN.rtbw
KQNvKP.rtbw
KQNvKQ.rtbw
KQNvKR.rtbw
KQPPvK.rtbw
KQPvK.rtbw 
KQPvKB.rtbw
KQPvKN.rtbw
KQPvKP.rtbw
KQPvKQ.rtbw
KQPvKR.rtbw
KQQBvK.rtbw
KQQNvK.rtbw
KQQPvK.rtbw
KQQQvK.rtbw
KQQRvK.rtbw
KQQvK.rtbw 
KQQvKB.rtbw
KQQvKN.rtbw
KQQvKP.rtbw
KQQvKQ.rtbw
KQQvKR.rtbw
KQRBvK.rtbw
KQRNvK.rtbw
KQRPvK.rtbw
KQRRvK.rtbw
KQRvK.rtbw 
KQRvKB.rtbw
KQRvKN.rtbw
KQRvKP.rtbw
KQRvKQ.rtbw
KQRvKR.rtbw
KQvK.rtbw  
KQvKB.rtbw 
KQvKN.rtbw 
KQvKP.rtbw 
KQvKQ.rtbw 
KQvKR.rtbw 
KRBBvK.rtbw
KRBNvK.rtbw
KRBPvK.rtbw
KRBvK.rtbw 
KRBvKB.rtbw
KRBvKN.rtbw
KRBvKP.rtbw
KRBvKQ.rtbw
KRBvKR.rtbw
KRNNvK.rtbw
KRNPvK.rtbw
KRNvK.rtbw 
KRNvKB.rtbw
KRNvKN.rtbw
KRNvKP.rtbw
KRNvKQ.rtbw
KRNvKR.rtbw
KRPPvK.rtbw
KRPvK.rtbw 
KRPvKB.rtbw
KRPvKN.rtbw
KRPvKP.rtbw
KRPvKQ.rtbw
KRPvKR.rtbw
KRRBvK.rtbw
KRRNvK.rtbw
KRRPvK.rtbw
KRRRvK.rtbw
KRRvK.rtbw 
KRRvKB.rtbw
KRRvKN.rtbw
KRRvKP.rtbw
KRRvKQ.rtbw
KRRvKR.rtbw
KRvK.rtbw  
KRvKB.rtbw 
KRvKN.rtbw 
KRvKP.rtbw 
KRvKR.rtbw
"""

# %%
files = text.splitlines()
# remove extension
files = [f.strip()[:-5] for f in files]
# sort by length, then alphabetically
files.sort(key=lambda f: (len(f), f))
print("\n".join(files))

# print something formatted like this:
"""
FILES=(
    # --- 3 PIECES ---
    "KPvK" "KQvK" "KRvK" "KBvK" "KNvK"

    # --- 4 PIECES: NO PAWNS ---
    "KBvKB" "KBvKN" "KBBvK" "KBNvK" 
    "KNvKN" "KNNvK" 
    "KQvKB" "KQvKN" "KQvKQ" "KQvKR"
    "KRvKB" "KRvKN" "KRvKR"
    "KRRvK" "KQBvK" "KQNvK" "KQRvK"
    "KRBvK" "KRNvK"

    # --- 4 PIECES: WITH PAWNS ---
    "KPPvK" 
    "KBPvK" "KBvKP"
    "KNPvK" "KNvKP"
    "KQPvK" "KQvKP"
    "KRPvK" "KRvKP"

    # promotion endings
    "KQQvK"
)
"""

print(f"""FILES=(
    # --- 3 PIECES: {len([f for f in files if len(f) == 4])} ---
    \"{'\" \"'.join(f for f in files if len(f) == 4)}\"

    # --- 4 PIECES: {len([f for f in files if len(f) == 5])} ---
    \"{'\" \"'.join(f for f in files if len(f) == 5)}\"

    # --- 5 PIECES: {len([f for f in files if len(f) == 6])} ---
    \"{'\" \"'.join(f for f in files if len(f) == 6)}\"
)""")
# Out:
# KBvK
# KNvK
# KPvK
# KQvK
# KRvK
# KBBvK
# KBNvK
# KBPvK
# KBvKB
# KBvKN
# KBvKP
# KNNvK
# KNPvK
# KNvKN
# KNvKP
# KPPvK
# KPvKP
# KQBvK
# KQNvK
# KQPvK
# KQQvK
# KQRvK
# KQvKB
# KQvKN
# KQvKP
# KQvKQ
# KQvKR
# KRBvK
# KRNvK
# KRPvK
# KRRvK
# KRvKB
# KRvKN
# KRvKP
# KRvKR
# KBBBvK
# KBBNvK
# KBBPvK
# KBBvKB
# KBBvKN
# KBBvKP
# KBBvKQ
# KBBvKR
# KBNNvK
# KBNPvK
# KBNvKB
# KBNvKN
# KBNvKP
# KBNvKQ
# KBNvKR
# KBPPvK
# KBPvKB
# KBPvKN
# KBPvKP
# KBPvKQ
# KBPvKR
# KNNNvK
# KNNPvK
# KNNvKB
# KNNvKN
# KNNvKP
# KNNvKQ
# KNNvKR
# KNPPvK
# KNPvKB
# KNPvKN
# KNPvKP
# KNPvKQ
# KNPvKR
# KPPPvK
# KPPvKB
# KPPvKN
# KPPvKP
# KPPvKQ
# KPPvKR
# KQBBvK
# KQBNvK
# KQBPvK
# KQBvKB
# KQBvKN
# KQBvKP
# KQBvKQ
# KQBvKR
# KQNNvK
# KQNPvK
# KQNvKB
# KQNvKN
# KQNvKP
# KQNvKQ
# KQNvKR
# KQPPvK
# KQPvKB
# KQPvKN
# KQPvKP
# KQPvKQ
# KQPvKR
# KQQBvK
# KQQNvK
# KQQPvK
# KQQQvK
# KQQRvK
# KQQvKB
# KQQvKN
# KQQvKP
# KQQvKQ
# KQQvKR
# KQRBvK
# KQRNvK
# KQRPvK
# KQRRvK
# KQRvKB
# KQRvKN
# KQRvKP
# KQRvKQ
# KQRvKR
# ...

# %%
f2 = """
KPvK KQvK KRvK KBvK KNvK
KBvKB KBvKN KBBvK KBNvK
KNvKN KNNvK 
KQvKB KQvKN KQvKQ KQvKR
KRvKB KRvKN KRvKR
KRRvK KQBvK KQNvK KQRvK
KRBvK KRNvK

KPPvK
KBPvK KBvKP
KNPvK KNvKP
KQPvK KQvKP
KRPvK KRvKP

KQQvK

KRPvKR KPPvKP KBPvKB KNNvKB KQQvKR KQRvKB KQQvKB KQQvKN KNNvKN KRRvKN KRRvKB KQQvKP KQRvKR KQQvKQ
"""
files2 = f2.split()
files2.sort(key=lambda f: (len(f.strip()), f.strip()))
print("\n".join(files2))
# Out:
# KBvK
# KNvK
# KPvK
# KQvK
# KRvK
# KBBvK
# KBNvK
# KBPvK
# KBvKB
# KBvKN
# KBvKP
# KNNvK
# KNPvK
# KNvKN
# KNvKP
# KPPvK
# KQBvK
# KQNvK
# KQPvK
# KQQvK
# KQRvK
# KQvKB
# KQvKN
# KQvKP
# KQvKQ
# KQvKR
# KRBvK
# KRNvK
# KRPvK
# KRRvK
# KRvKB
# KRvKN
# KRvKP
# KRvKR
# KBPvKB
# KNNvKB
# KNNvKN
# KPPvKP
# KQQvKB
# KQQvKN
# KQQvKP
# KQQvKQ
# KQQvKR
# KQRvKB
# KQRvKR
# KRPvKR
# KRRvKB
# KRRvKN

# %%
# compare the two lists
set1 = set(files)
set2 = set(files2)
print("In set1 but not in set2:", len(set1 - set2))
print(" ".join(sorted(set1 - set2)))
print("\nIn set2 but not in set1:", len(set2 - set1))
print(" ".join(sorted(set2 - set1)))

print("\nIn both sets:", len(set1 & set2))
print(" ".join(sorted(set1 & set2)))

print("\nIn set1:", len(set1))
print(" ".join(sorted(set1)))

print("\nIn set2:", len(set2))
print(" ".join(sorted(set2)))
# Out:
# In set1 but not in set2: 98
#  KBBBvK KBBNvK KBBPvK KBBvKB KBBvKN KBBvKP KBBvKQ KBBvKR KBNNvK KBNPvK KBNvKB KBNvKN KBNvKP KBNvKQ KBNvKR KBPPvK KBPvKN KBPvKP KBPvKQ KBPvKR KNNNvK KNNPvK KNNvKP KNNvKQ KNNvKR KNPPvK KNPvKB KNPvKN KNPvKP KNPvKQ KNPvKR KPPPvK KPPvKB KPPvKN KPPvKQ KPPvKR KPvKP KQBBvK KQBNvK KQBPvK KQBvKB KQBvKN KQBvKP KQBvKQ KQBvKR KQNNvK KQNPvK KQNvKB KQNvKN KQNvKP KQNvKQ KQNvKR KQPPvK KQPvKB KQPvKN KQPvKP KQPvKQ KQPvKR KQQBvK KQQNvK KQQPvK KQQQvK KQQRvK KQRBvK KQRNvK KQRPvK KQRRvK KQRvKN KQRvKP KQRvKQ KRBBvK KRBNvK KRBPvK KRBvKB KRBvKN KRBvKP KRBvKQ KRBvKR KRNNvK KRNPvK KRNvKB KRNvKN KRNvKP KRNvKQ KRNvKR KRPPvK KRPvKB KRPvKN KRPvKP KRPvKQ KRRBvK KRRNvK KRRPvK KRRRvK KRRvKP KRRvKQ KRRvKR
#
# In set2 but not in set1: 0
#
#
# In both sets: 48
# ...

# %%
bots = [('leelaqueenodds', 2470), ('boris-trapsky', 2068), ('simpleeval', 2158), ('lynx_bot', 2633), ('leelarogue', 2324), ('elmichess', 2172), ('resolutebot', 2945), ('humaia-strong', 2206), ('raspfish', 3016), ('halcyonbot', 2200), ('cheng-4', 2634), ('eubos', 2400), ('radianceengine', 2253), ('ravenengine', 2280), ('likeawizard-bot', 2309), ('duchessai', 2781), ('admete_bot', 2553), ('weiawaga', 2794), ('fathzer-jchess', 2198), ('honzovy-sachy-2', 2227), ('leelajester', 2230), ('moment-that-inspires', 3020), ('goldfish-engine', 2182), ('yobot_v2', 3011), ('odonata-bot', 2740), ('ajedrezchamberi', 2276), ('catriever', 2140), ('phalanx-xxv', 2461), ('fataliibot', 2361), ('pseudo-0', 2466), ('simbelmyne-bot', 2588), ('matmoi', 2052), ('pawn_git', 2795), ('motor-0', 2899), ('bot_adario', 2460), ('classic_bot-v2', 3023), ('pzchessbot', 2955), ('cheng-4-nn', 2804), ('cloudnetbot', 2975), ('bot64jaques', 2363), ('leelaanyodds', 2253), ('maello_bot', 2055), ('cheszter', 3016), ('peachfruit', 2390), ('pseudo-1', 2871), ('deepbecky', 2305), ('abcd_engine', 3021), ('gnupassant', 2367), ('european_chess_bot', 2964), ('wolfuhfuhbot', 2232), ('archduchessbot', 2036), ('byte-knight', 2369), ('aconcaguabot', 2256), ('aetherbot', 2107), ('patzerbot135', 2026), ('borkatower', 3002), ('fischer_bot', 3014), ('bitbitbot', 2602), ('abdcebot', 3026), ('refutemygambit', 2768), ('grail-bot', 2702), ('renegadeengine', 2874), ('jpg-bot', 2956), ('thunfisch-bot', 2310), ('eichkatzerl', 2497), ('pruningbot', 2879), ('prokopakop', 2536), ('hyperopic', 2114), ('mastacticateoriabot', 2921), ('stickshark99', 2091), ('casanchess-nnue', 2381), ('tutorialbotelmejor', 2180), ('cinder-bot', 3022), ('vortexinbrp', 2722), ('nebubot', 2538), ('bretemabot', 2665), ('troutbot', 2272), ('tigrament', 2116), ('imranmelikovbot', 2182), ('mockba_cbepxcekpetho', 2925), ('recklessengine', 3019), ('groshboss', 2164), ('sykorabot', 2612), ('ursus_bot', 2850), ('mdbot', 3011), ('turk_gambit', 2150), ('aliceshiro', 3000), ('mac-bot', 2379), ('sybaibot', 3000), ('stalebot', 3023), ('chessiverse_raak', 2106), ('ilovecatgirl', 2848), ('blobfish-bot', 2170), ('endspiel-engine', 2787), ('aaronsengine', 2170), ('senkabalabot', 2097), ('cutebot', 3012), ('joan_clone', 3007), ('omegazero-bot', 2189), ('darkelectronbot', 2061), ('morabandbot', 2406), ('tombot1234', 2299), ('cutecassia', 2311), ('thealexdestroyer', 2564), ('mate1-bot', 2047), ('chessmindbots', 2322), ('ratsu-bot', 2189), ('codabot', 2949), ('ficheallrs', 2088), ('ophanimdotonline', 3000), ('rpibot73', 2333), ('usunfish', 2250), ('coda_bot', 2947), ('khanhbell12345', 2836), ('arkiplayschess', 2660), ('mcdostosckfantydraw', 3000)]
bots = sorted(bots, key=lambda x: x[1], reverse=True)
# distribution of ratings
import matplotlib.pyplot as plt
import numpy as np
ratings = [x[1] for x in bots]
plt.hist(ratings, bins=np.arange(2000, 3100, 100))
plt.xlabel("Rating")
plt.ylabel("Number of bots")
plt.title("Distribution of Lichess Bot Ratings")
plt.show()

# %%
bots2 = [('maia1', 1395), ('maia5', 1506), ('maia9', 1628), ('leelaqueenodds', 2470), ('leelapieceodds', 2000), ('leelarookodds', 3070), ('leelaknightodds', 3340), ('worstfish', 1500), ('humaia', 1304), ('sargon-1ply', 1185), ('boris-trapsky', 2068), ('sargon-2ply', 1188), ('anti-bot', 1500), ('variantsbot', 1500), ('turkjs', 1640), ('simpleeval', 2158), ('lynx_bot', 2633), ('chesschildren', 1871), ('leelarogue', 2324), ('turochamp-1ply', 1318), ('catnail', 1500), ('bernstein-2ply', 1158), ('turochamp-2ply', 1321), ('elmichess', 2172), ('sargon-3ply', 1388), ('resolutebot', 2945), ('garbobot', 1930), ('humaia-strong', 2206), ('leelaqueenforknight', 2000), ('larryz-alterego', 849), ('sargon-4ply', 1422), ('raspfish', 3016), ('jibbby', 1597), ('bernstein-4ply', 1311), ('charibot', 2000), ('stupidfishbotbydscs', 694), ('halcyonbot', 2200), ('virutor', 1875), ('cheng-4', 2634), ('eubos', 2400), ('usunfish-l0', 739), ('edwardkillick', 1089), ('maia9_10n', 1616), ('radianceengine', 2253), ('darkonweakbot', 1646), ('schnecken_bot', 1419), ('ravenengine', 2280), ('likeawizard-bot', 2309), ('duchessai', 2781), ('admete_bot', 2553), ('weiawaga', 2794), ('fathzer-jchess', 2198), ('honzovy-sachy-2', 2227), ('maia9_30n', 1747), ('leelajester', 2230), ('partner3615diago', 597), ('demolito_l4', 1613), ('usunfish-l1', 1125), ('moment-that-inspires', 3020), ('hummus-bot', 2003), ('chamberiajedrez', 1503), ('goldfish-engine', 2182), ('croco_little_bot', 962), ('demolito_l3', 1455), ('honzovy-sachy', 1817), ('sf_bot1nok', 3034), ('demolito_l5', 1739), ('yobot_v2', 3011), ('nilatacbot', 1500), ('odonata-bot', 2740), ('ajedrezchamberi', 2276), ('melsh_bot', 1587), ('joshsbot', 1354), ('puisne', 1245), ('bot1nokk', 3031), ('annie_archy', 2000), ('demolito_l6', 1855), ('catriever', 2140), ('phalanx-xxv', 2461), ('fataliibot', 2361), ('baby_eubos', 1825), ('slowmate_bot', 1108), ('pseudo-0', 2466), ('simbelmyne-bot', 2588), ('demolito_l1', 1321), ('demolito_l2', 1374), ('louischess48-6k', 1140), ('c0kval', 1580), ('bot5551', 1772), ('crabstick-engine', 1260), ('mochi_bot', 1741), ('matmoi', 2052), ('nexastrat', 1175), ('ai-con', 1757), ('gryndor', 2000), ('maia2200_10n', 1633), ('mr_sandbar', 1060), ('pawn_git', 2795), ('bot1e', 3038), ('queensgambot', 1582), ('ashnostromo', 1950), ('dala-900', 958), ('motor-0', 2899), ('v7p3r_bot', 1311), ('bot_adario', 2460), ('classic_bot-v2', 3023), ('pzchessbot', 2955), ('bfiedler-bot', 1825), ('ellen_replay', 1816), ('rudim-bot', 1837), ('sseh-c', 1964), ('stockfishlowdepth', 1638), ('kopyto_dev', 1991), ('cheng-4-nn', 2804), ('chessiverse_pawnza', 1450), ('cloudnetbot', 2975), ('aggressivestockfish', 2860), ('croco_bot', 1346), ('c0br4_bot', 1376), ('bot64jaques', 2363), ('leelaanyodds', 2253), ('dala-1300', 1317), ('is_boss', 3127), ('piglet_engine', 1872), ('maello_bot', 2055), ('cheszter', 3016), ('r0bspierre', 1522), ('peachfruit', 2390), ('strawberrychess1', 1223), ('dala-700', 892), ('pseudo-1', 2871), ('scalaqueen', 1572), ('perl-gigachess', 1307), ('deepbecky', 2305), ('dala-1100', 1216), ('abcd_engine', 3021), ('walleye_bot', 2021), ('gnupassant', 2367), ('sxphia', 1856), ('european_chess_bot', 2964), ('bot913', 3035), ('wolfuhfuhbot', 2232), ('ailedbot', 866), ('debzero', 1782), ('archduchessbot', 2036), ('goopis', 1526), ('byte-knight', 2369), ('aconcaguabot', 2256), ('aetherbot', 2107), ('patzerbot135', 2026), ('dala-1600', 1531), ('borkatower', 3002), ('fischer_bot', 3014), ('usunfish-l7', 1536), ('worst-ai', 2733), ('vietnamesecoffee', 1680), ('chessiverse_ethan', 1407), ('yuligpro5', 2908), ('bitbitbot', 2602), ('abdcebot', 3026), ('terconari', 1389), ('nanozero', 1922), ('topasbot', 1939), ('refutemygambit', 2768), ('grail-bot', 2702), ('throrbjorn', 1913), ('renegadeengine', 2874), ('jpg-bot', 2956), ('strawberrychessdev', 1569), ('martuni', 2025), ('thunfisch-bot', 2310), ('eichkatzerl', 2497), ('uzenatch', 1722), ('thanatos_engine_v7', 1723), ('vanibot', 1833), ('pi0w', 2007), ('hynobiuschess', 1845), ('weakstash', 1843), ('xewali', 1998), ('pruningbot', 2879), ('prokopakop', 2536), ('confidencebuilder', 1250), ('hyperopic', 2114), ('mastacticateoriabot', 2921), ('stickshark99', 2091), ('chessiverse_luc', 1655), ('casanchess-nnue', 2381), ('o-rei-cx', 1721), ('friendlybot_1700', 3003), ('nice_bot', 1790), ('tutorialbotelmejor', 2180), ('slow-and-stupid', 2013), ('cinder-bot', 3022), ('vortexinbrp', 2722), ('nebubot', 2538), ('spaceengine', 1691), ('bretemabot', 2665), ('troutbot', 2272), ('cassandra-jl', 1948), ('crotex', 1551), ('tigrament', 2116), ('axiom_bot', 1903), ('bobybot', 2000), ('imranmelikovbot', 2182), ('uxugin-bot', 1594), ('wojtmic-bot', 1808), ('raven030', 1668), ('crocodile_bot', 1430), ('mockba_cbepxcekpetho', 2925), ('recklessengine', 3019), ('flower-queen', 1851), ('groshboss', 2164), ('sykorabot', 2612), ('cloudia-chess', 1690), ('byteslayer-chessbot', 1273), ('ursus_bot', 2850), ('mdbot', 3011), ('turk_gambit', 2150), ('aliceshiro', 3000), ('hydray', 2007), ('mac-bot', 2379), ('sybaibot', 3000), ('stalebot', 3023), ('grindle_x_bot1', 1323), ('overfitted', 1852), ('chessiverse_raak', 2106), ('ilovecatgirl', 2848), ('blobfish-bot', 2170), ('endspiel-engine', 2787), ('sj_norbot', 1852), ('aaronsengine', 2170), ('senkabalabot', 2097), ('cutebot', 3012), ('joan_clone', 3007), ('mazybot', 1575), ('omegazero-bot', 2189), ('darkelectronbot', 2061), ('takticprochess', 3035), ('morabandbot', 2406), ('tombot1234', 2299), ('cutecassia', 2311), ('thealexdestroyer', 2564), ('mate1-bot', 2047), ('lemuffinbot', 1871), ('chessmindbots', 2322), ('ratsu-bot', 2189), ('cerberus_bot', 1622), ('mimirbot', 1987), ('laura-bot', 1941), ('larsskakrobot', 1920), ('codabot', 2949), ('neurosocute', 3034), ('ficheallrs', 2088), ('scholia', 2002), ('ophanimdotonline', 3000), ('rpibot73', 2333), ('usunfish', 2250), ('milanbot', 1676), ('dala-2000', 1824), ('coda_bot', 2947), ('khanhbell12345', 2836), ('arkiplayschess', 2660), ('mcdostosckfantydraw', 3000)]
bots2 = sorted(bots2, key=lambda x: x[1], reverse=True)
# distribution of ratings
import matplotlib.pyplot as plt
import numpy as np
ratings2 = [x[1] for x in bots2]
plt.hist(ratings2, bins=np.arange(1000, 3500, 100))
plt.xlabel("Rating")
plt.ylabel("Number of bots")
plt.title("Distribution of Lichess Bot Ratings (including Maia and other low-rated bots)")
plt.show()

# %%
print("\nBots with rating >= 3000:")
for bot in bots2:
    if bot[1] >= 3000:
        print(f"  {bot[0]}: {bot[1]}")
# Out:
# Bots with rating >= 3000:
#   leelaknightodds: 3340
#   is_boss: 3127
#   leelarookodds: 3070
#   bot1e: 3038
#   bot913: 3035
#   takticprochess: 3035
#   sf_bot1nok: 3034
#   neurosocute: 3034
#   bot1nokk: 3031
#   abdcebot: 3026
#   classic_bot-v2: 3023
#   stalebot: 3023
#   cinder-bot: 3022
#   abcd_engine: 3021
#   moment-that-inspires: 3020
#   recklessengine: 3019
#   raspfish: 3016
#   cheszter: 3016
#   fischer_bot: 3014
#   cutebot: 3012
#   yobot_v2: 3011
#   mdbot: 3011
#   joan_clone: 3007
#   friendlybot_1700: 3003
#   borkatower: 3002
#   aliceshiro: 3000
#   sybaibot: 3000
#   ophanimdotonline: 3000
#   mcdostosckfantydraw: 3000
